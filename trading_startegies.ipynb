# %%
from trading_indicators import MovingAverageCrossover
from trading_indicators import RelativeStrengthIndex
from trading_indicators import BollingerBands
from trading_indicators import MACDCrossOver
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.34.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
ma_cross = MovingAverageCrossover(symbol='TCS',start='2023-01-01',end='2024-02-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ma_cross.df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-01-02  3261.000000  3266.850098  3235.199951  3261.449951  3104.664307
# 2023-01-03  3252.000000  3320.000000  3245.300049  3311.350098  3152.165283
# 2023-01-04  3306.699951  3327.350098  3286.199951  3314.649902  3155.306396
# 2023-01-05  3330.199951  3337.300049  3281.949951  3311.100098  3151.927002
# 2023-01-06  3300.000000  3301.550049  3200.000000  3211.550049  3057.163086
# ...                 ...          ...          ...          ...          ...
# 2024-01-24  3880.000000  3883.649902  3805.600098  3841.800049  3795.979980
# 2024-01-25  3839.899902  3861.000000  3778.699951  3810.300049  3764.855713
# 2024-01-29  3800.800049  3820.000000  3780.850098  3801.000000  3755.666504
# 2024-01-30  3807.449951  3847.800049  3787.000000  3800.550049  3755.221924
# 2024-01-31  3811.199951  3834.000000  3796.449951  3815.949951  3770.438232
#
#              Volume
# Date
# 2023-01-02   709547
# ...

# %% [markdown]
# # Entry Exit Indicator using SMA and EMA
#
# 1] when fast EMA cuts slow EMA from the bottom the signal is "buy"
#
# 2] when fast EMA cuts slow EMA from the above the signal is "sell"
#
# Note: you can use other pairs of EMA also

# %%
data_ma = ma_cross.plot_moving_average_crossover(featurename='Close',short_window=7,long_window=21,ma_type='simple')
# Out:
# e:\Python_for_finance\trading_bot.py:43: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %% [markdown]
# # RSI Analysis
#
# The Relative Strength Index (RSI) is a momentum oscillator that measures the speed and change of price movements. It oscillates between 0 and 100 and is used to identify overbought or oversold conditions in a security.
#
# Here's what the RSI indicates:
#
# Overbought Conditions: When the RSI value exceeds a certain threshold (often 70), it suggests that the security may be overbought. This means that the price has risen too quickly and may be due for a correction or reversal.
#
# Oversold Conditions: When the RSI value falls below a certain threshold (often 30), it suggests that the security may be oversold. This means that the price has fallen too quickly and may be due for a rebound or reversal.

# %%
rsi = RelativeStrengthIndex(symbol='TCS',start='2023-01-01',end='2024-02-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
rsi.plot_rsi(period=14,upper=70,lower=30,featurename='Close')
# Out:
# e:\Python_for_finance\trading_bot.py:109: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# e:\Python_for_finance\trading_bot.py:109: FutureWarning:
#
# ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
bollinger = BollingerBands(symbol='TCS',start='2023-01-01',end='2024-02-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
bollinger.plot_bollinger_bands(window=14,std=2,featurename='Close')
# Out:
# <div>                            <div id="ee1b1dcd-1ee1-4f2f-8431-8ad437db2b78" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee1b1dcd-1ee1-4f2f-8431-8ad437db2b78")) {                    Plotly.newPlot(                        "ee1b1dcd-1ee1-4f2f-8431-8ad437db2b78",                        [{"close":[3261.449951171875,3311.35009765625,3314.64990234375,3311.10009765625,3211.550048828125,3319.949951171875,3286.39990234375,3328.699951171875,3334.35009765625,3374.550048828125,3334.050048828125,3378.39990234375,3390.0,3373.10009765625,3363.10009765625,3414.89990234375,3436.300048828125,3429.75,3411.050048828125,3433.64990234375,3358.699951171875,3408.35009765625,3460.39990234375,3482.300048828125,3459.949951171875,3472.550048828125,3520.10009765625,3540.
# ...

# %% [markdown]
# # MACD Indicator
#
# Interpreting the MACD (Moving Average Convergence Divergence) result involves understanding the relationship between the MACD line, the signal line.
#
# When the MACD line crosses above the signal line, it indicates a bullish signal or buying opportunity. Conversely, when the MACD line crosses below the signal line, it signals a bearish trend or selling opportunity.

# %%
macd = MACDCrossOver(symbol='TCS',start='2023-01-01',end='2024-02-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
macd.plot_macd(fastperiod=7,slowperiod=21,signalperiod=14,featurename='Close')
# Out:
# <div>                            <div id="46fe8104-52a9-4a04-978d-eb1437a2889b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46fe8104-52a9-4a04-978d-eb1437a2889b")) {                    Plotly.newPlot(                        "46fe8104-52a9-4a04-978d-eb1437a2889b",                        [{"line":{"color":"blue"},"mode":"lines","name":"MACD","x":["2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-09T00:00:00","2023-01-10T00:00:00","2023-01-11T00:00:00","2023-01-12T00:00:00","2023-01-13T00:00:00","2023-01-16T00:00:00","2023-01-17T00:00:00","2023-01-18T00:00:00","2023-01-19T00:00:00","2023-01-20T00:00:00","2023-01-23T00:00:00","2023-01-24T00:00:00","2023-01-25T00:00:00","2023-01-27T
# ...
